# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/monroe county car crach 2003-2015.csv',encoding='latin1')

# %%
data.head(10)
# Out:
#    Year  Month  Day Weekend?    Hour Collision Type         Injury Type  \
# 0  2015      1    5  Weekday     0.0          2-Car   No injury/unknown
# 1  2015      1    6  Weekday  1500.0          2-Car   No injury/unknown
# 2  2015      1    6  Weekend  2300.0          2-Car  Non-incapacitating
# 3  2015      1    7  Weekend   900.0          2-Car  Non-incapacitating
# 4  2015      1    7  Weekend  1100.0          2-Car   No injury/unknown
# 5  2015      1    6  Weekday  1800.0          2-Car   No injury/unknown
# 6  2015      1    6  Weekday  1200.0          2-Car   No injury/unknown
# 7  2015      1    6  Weekday  1400.0          1-Car      Incapacitating
# 8  2015      1    7  Weekend  1400.0          2-Car   No injury/unknown
# 9  2015      1    7  Weekend  1600.0          1-Car   No injury/unknown
#
#                              Primary Factor        Reported_Location  \
# 0     OTHER (DRIVER) - EXPLAIN IN NARRATIVE               1ST & FESS
# 1                     FOLLOWING TOO CLOSELY            2ND & COLLEGE
# 2                 DISREGARD SIGNAL/REG SIGN    BASSWOOD & BLOOMFIELD
# 3             FAILURE TO YIELD RIGHT OF WAY           GATES & JACOBS
# 4             FAILURE TO YIELD RIGHT OF WAY                    W 3RD
# 5             FAILURE TO YIELD RIGHT OF WAY           BURKS & WALNUT
# 6  DRIVER DISTRACTED - EXPLAIN IN NARRATIVE  SOUTH CURRY PIKE LOT 71
# 7               ENGINE FAILURE OR DEFECTIVE          NORTH LOUDEN RD
# 8                     FOLLOWING TOO CLOSELY          LIBERTY & W 3RD
# 9                        RAN OFF ROAD RIGHT        PATTERSON & W 3RD
#
#     Latitude  Longitude
# 0  39.159207 -86.525874
# 1  39.161440 -86.534848
# 2  39.149780 -86.568890
# 3  39.165655 -86.575956
# 4  39.164848 -86.579625
# 5  39.126670 -86.531370
# 6  39.150825 -86.584899
# 7  39.199272 -86.637024
# 8  39.164610 -86.579130
# 9  39.163440 -86.551280

# %%
data.tail(10)
# Out:
#        Year  Month  Day Weekend?    Hour Collision Type         Injury Type  \
# 18739  2011     10    2  Weekday  1500.0        3+ Cars  Non-incapacitating
# 18740  2011     11    4  Weekday   300.0          2-Car   No injury/unknown
# 18741  2011     12    1  Weekday  2000.0          2-Car   No injury/unknown
# 18742  2011      6    3  Weekday  1700.0        3+ Cars  Non-incapacitating
# 18743  2011      6    3  Weekday   800.0        3+ Cars   No injury/unknown
# 18744  2011      9    2  Weekday  1200.0          2-Car   No injury/unknown
# 18745  2011     10    4  Weekday   900.0          2-Car   No injury/unknown
# 18746  2011      4    2  Weekday  1800.0          2-Car   No injury/unknown
# 18747  2011      6    5  Weekday  2000.0          2-Car   No injury/unknown
# 18748  2011      1    7    Weeke     NaN            NaN                 NaN
#
#                                  Primary Factor       Reported_Location  \
# 18739             FAILURE TO YIELD RIGHT OF WAY           3RD ST & CORY
# 18740                              UNSAFE SPEED              S ADAMS ST
# 18741     OTHER (DRIVER) - EXPLAIN IN NARRATIVE              S ADAMS ST
# 18742  DRIVER DISTRACTED - EXPLAIN IN NARRATIVE    KIMBEL & WEST 3RD ST
# 18743                     FOLLOWING TOO CLOSELY  OPPORTUNITY & W 3RD ST
# 18744                                       NaN               W 3 ST ST
# 18745    OTHER (VEHICLE) - EXPLAIN IN NARRATIVE              W THIRD ST
# 18746                            UNSAFE BACKING                E 3RD ST
# 18747                            UNSAFE BACKING                E 3RD ST
# 18748                                       NaN                     NaN
#
#         Latitude  Longitude
# 18739  39.164544 -86.560096
# 18740  39.164544 -86.552192
# 18741  39.164544 -86.552192
# 18742  39.164540 -86.567990
# 18743  39.164530 -86.567067
# 18744  39.164526 -86.566518
# 18745  39.164526 -86.566609
# 18746  39.164522 -86.551104
# 18747  39.164521 -86.551072
# 18748        NaN        NaN

# %%
data.shape
# Out:
# (18749, 11)

# %%
data.size
# Out:
# 206239

# %%
data.describe()
# Out:
#                Year         Month           Day          Hour      Latitude  \
# count  18749.000000  18749.000000  18749.000000  18748.000000  18718.000000
# mean    2013.245026      6.666542      4.199797   1334.515682     36.763260
# std        1.315990      3.510866      1.906324    538.661322      9.399490
# min     2011.000000      1.000000      1.000000      0.000000      0.000000
# 25%     2012.000000      4.000000      3.000000   1000.000000     39.148144
# 50%     2013.000000      7.000000      4.000000   1400.000000     39.164720
# 75%     2014.000000     10.000000      6.000000   1700.000000     39.176454
# max     2015.000000     12.000000      7.000000   2300.000000     41.228665
#
#           Longitude
# count  18718.000000
# mean     -81.221394
# std       20.803866
# min      -88.959213
# 25%      -86.556117
# 50%      -86.532400
# 75%      -86.512370
# max       86.596363

# %%
data.columns
# Out:
# Index(['Year', 'Month', 'Day', 'Weekend?', 'Hour', 'Collision Type',
#        'Injury Type', 'Primary Factor', 'Reported_Location', 'Latitude',
#        'Longitude'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=18749, step=1)

# %%
data.isnull().sum()
# Out:
# Year                   0
# Month                  0
# Day                    0
# Weekend?               0
# Hour                   1
# Collision Type         1
# Injury Type            1
# Primary Factor       389
# Reported_Location      7
# Latitude              31
# Longitude             31
# dtype: int64

# %%
sns.heatmap(data.isnull(),cmap  ='viridis',cbar=False)
# Out:
# <Axes: >

# %%
data['Weekend?'].unique()
# Out:
# array(['Weekday', 'Weekend', 'Weeke'], dtype=object)

# %%
data['Weekend?'] =data['Weekend?'].map({'Weekday':0,'Weekend':1})

# %%
data['DayOfWeek'] = pd.to_datetime(data[['Year','Month','Day']]).dt.day_name()

# %%
plt.figure(figsize=(10,6))
sns.countplot(x=  'DayOfWeek',data=data,order= ['Monday','Tuesday','Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])
plt.title('Crashes by Day of Week')
plt.show()

# %%
#time analysis

plt.figure(figsize=(20,6))
sns.countplot(x = 'Hour',data=data)
plt.title('Crashes by hour')
plt.xlabel("Hour of the Day")
plt.show()

# %%
# Geospatial Analysis

plt.scatter(data['Longitude'],data['Latitude'],alpha =0.5)
plt.title('Geospatial Distribution of crashes')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %%
#time analysis

plt.figure(figsize=(20,6))
sns.countplot(x = 'Hour',data=data)
plt.title('Crashes by hour')
plt.xlabel("Hour of the Day")
plt.show()

# %%
# Collision Type Analysis
plt.figure(figsize=(10,6))
sns.countplot(x = 'Collision Type',data= data)
plt.title('Distribution of Collision Types')
plt.xticks(rotation = 45)
plt.show()

# %%
# Injury Analysis
plt.figure(figsize = (10,6))
sns.countplot(x ='Injury Type',data=data)
plt.title('Distribution of Injury Types')
plt.xticks(rotation = 90)
plt.show()

# %%
# Primary Factor Analysis

plt.figure(figsize=(10,6))
sns.countplot(x = "Primary Factor",data=data)
plt.title('Distribution of primary factors')
plt.xticks(rotation =90)
plt.show()

# %%
# Selecting numerical columns
numerical_columns = data.select_dtypes(include=['float64', 'int64']).columns
numerical_data = data[numerical_columns]

# %%
# Plotting Correlation Matrix
correlation_matrix = numerical_data.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix of Numerical Features')
plt.show()
